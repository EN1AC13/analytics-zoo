# %% [markdown]
# # Automated ML for time series predicion

# %% [markdown]
# We used one of the dataset in [Numenta Anomaly Benchmark (NAB)](https://github.com/numenta/NAB) for demo, i.e. NYC taxi passengers dataset, which contains 10320 records, each indicating the total number of taxi passengers in NYC at a corresonponding time spot.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 0. Helper function definations

# %%
# plot the predicted values and actual values (for the test data)
def plot_result(test_df, pred_df, dt_col="timestamp", value_col="value", past_seq_len=1):
    # target column of dataframe is "value"
    # past sequence length is 50
    pred_value = pred_df[value_col].values
    true_value = test_df[value_col].values[past_seq_len:]
    fig, axs = plt.subplots(figsize=(12, 5))

    axs.plot(pred_df[dt_col], pred_value, color='red', label='predicted values')
    axs.plot(test_df[dt_col][past_seq_len:], true_value, color='blue', label='actual values')
    axs.set_title('the predicted values and actual values (for the test data)')

    plt.xlabel(dt_col)
    plt.xticks(rotation=45)
    plt.ylabel('number of taxi passengers')
    plt.legend(loc='upper left')
    plt.show()

# %%
# plot results of multi step forecasting
# plot at most five values for better view
# plot the predicted values and actual values (for the test data)
def plot_less_five_step_result(test_df, pred_df, dt_col="timestamp", value_col="value", past_seq_len=1):
    fig, axs = plt.subplots(figsize=(12, 5))
    target_value = test_df[value_col].values[past_seq_len:]
    axs.plot(test_df[dt_col][past_seq_len:], target_value, color='blue', label='actual values')

    value_cols=["{}_{}".format(value_col, i) for i in range(min(pred_df.shape[1] - 1, 5))]
    time_delta = pred_df[dt_col][1] - pred_df[dt_col][0]
    plot_color = ["g", "r", "c", "m", "y"]
    for i in range(len(value_cols)):
        pred_value = pred_df[value_cols[i]].values
        pred_dt = pred_df[dt_col].values + time_delta * i
        axs.plot(pred_dt, pred_value, color=plot_color[i], label='predicted values' + str(i))

    axs.set_title('the predicted values and actual values (for the test data)')

    plt.xlabel(dt_col)
    plt.xticks(rotation=45)
    plt.ylabel('number of taxi passengers')
    plt.legend(loc='upper left')
    plt.show()

# %%
# plot results of multi step forecasting
# plot result of multi step forecasting
# plot the predicted values and actual values (for the test data)
def plot_first_last_step_result(test_df, pred_df, dt_col="timestamp", value_col="value", past_seq_len=1):
    fig, axs = plt.subplots(figsize=(12, 5))
    target_value = test_df[value_col].values[past_seq_len:]
    axs.plot(test_df[dt_col][past_seq_len:], target_value, color='blue', label='actual values')

    value_cols=["{}_{}".format(value_col, i) for i in range(pred_df.shape[1] - 1)]
    time_delta = pred_df[dt_col][1] - pred_df[dt_col][0]
  
    pred_value_first = pred_df[value_cols[0]].values
    pred_dt_first = pred_df[dt_col].values
    axs.plot(pred_dt_first, pred_value_first, color="g", label='first predicted values')
 
    pred_value_last = pred_df[value_cols[-1]].values
    pred_dt_last = pred_df[dt_col].values + time_delta * (len(value_cols)-1)
    axs.plot(pred_dt_last, pred_value_last, color="r", label='last predicted values')

    axs.set_title('the predicted values and actual values (for the test data)')

    plt.xlabel(dt_col)
    plt.xticks(rotation=45)
    plt.ylabel('number of taxi passengers')
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# ## 1. load data

# %%
import os
import pandas as pd
import numpy as np

import matplotlib
matplotlib.use('Agg')
# %pylab inline
import matplotlib.dates as md
from matplotlib import pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Now we download the dataset and load it into a pandas dataframe.
# Run the script `$ANALYTICS_ZOO_HOME/dist/bin/data/NAB/nyc_taxi/get_nyc_taxi.sh` to download the raw data

# %%
# load nyc taxi data
try:
    dataset_path = os.getenv("ANALYTICS_ZOO_HOME")+"/bin/data/NAB/nyc_taxi/nyc_taxi.csv"
    raw_df = pd.read_csv(dataset_path)
except Exception as e:
    print("nyc_taxi.csv doesn't exist")
    print("you can run $ANALYTICS_ZOO_HOME/bin/data/NAB/nyc_taxi/get_nyc_taxi.sh to download nyc_taxi.csv")

# %% [markdown]
# Below are some example records of the data

# %%
raw_df.head(5)
# Out:
#              timestamp  value
# 0  2014-07-01 00:00:00  10844
# 1  2014-07-01 00:30:00   8127
# 2  2014-07-01 01:00:00   6210
# 3  2014-07-01 01:30:00   4656
# 4  2014-07-01 02:00:00   3820

# %% [markdown]
# Convert string timestamp to TimeStamp

# %%
df = pd.DataFrame(pd.to_datetime(raw_df.timestamp))
df["value"] = raw_df["value"]
df.head()
# Out:
#             timestamp  value
# 0 2014-07-01 00:00:00  10844
# 1 2014-07-01 00:30:00   8127
# 2 2014-07-01 01:00:00   6210
# 3 2014-07-01 01:30:00   4656
# 4 2014-07-01 02:00:00   3820

# %% [markdown]
# You can use train_val_test_split to split the whole dataset into train/val/test sets. There will be two columns in the output dataframe: "timestamp" and "value", where the data type of "timestamp" column is datetime64.

# %%
from zoo.automl.common.util import train_val_test_split
train_df, val_df, test_df = train_val_test_split(df, val_ratio=0.1, test_ratio=0.1)

# %%
train_df.describe()
# Out:
#               value
# count   8256.000000
# mean   15421.585514
# std     6871.989592
# min     1431.000000
# 25%    11040.000000
# 50%    17014.500000
# 75%    20032.250000
# max    39197.000000

# %%
train_df.head()
# Out:
#             timestamp  value
# 0 2014-07-01 00:00:00  10844
# 1 2014-07-01 00:30:00   8127
# 2 2014-07-01 01:00:00   6210
# 3 2014-07-01 01:30:00   4656
# 4 2014-07-01 02:00:00   3820

# %%
# shape of the dataframe
print("The shape of train_df is", train_df.shape)
print("The shape of val_df is", val_df.shape)
print("The shape of test_df is", test_df.shape)
# Out:
# The shape of train_df is (8256, 2)
# The shape of val_df is (1032, 2)
# The shape of test_df is (1032, 2)

# %%
# visualisation of anomaly throughout time in train_df
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

fig, ax = plt.subplots(figsize=(12, 5))
# pd.plotting.deregister_matplotlib_converters()

ax.plot(train_df['timestamp'], train_df['value'], color='blue', linewidth=0.6)
ax.set_title('NYC taxi passengers throughout time')

plt.xlabel('timestamp')
plt.xticks(rotation=45) 
plt.ylabel('The Number of NYC taxi passengers')
plt.legend(loc='upper left')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## 2. Train and validation

# %% [markdown]
# You can use analytices zoo automl to predict time series data by simply define a `TimeSequencePredictor`.
#
# We use feature tools to generate features from the given datetime. The generated features are \['HOUR', 'DAY', 'MONTH'. 'IS_AWAKE', 'IS_BUSY_HOURS'\]. Our feature space comprises these generated features as well as the original inputs such as \['datetime','value','extra_features'\].
#
# Currently, We use RNN to learn from 50 previous values, and predict just the 1 next value. You can specify the sequence length to predict while creating `TimeSequencePredictor` with arg: `future_seq_len`.

# %%
# build time sequence predictor
from zoo.automl.regression.time_sequence_predictor import *

# you need to specify the name of datetime column and target column
# The default names are "timestamp" and "value" respectively.
tsp = TimeSequencePredictor(dt_col="timestamp",
                            target_col="value",
                            extra_features_col=None)

# %%
from zoo import init_spark_on_local
from zoo.ray import RayContext
sc = init_spark_on_local(cores=4)
ray_ctx = RayContext(sc=sc, object_store_memory="1g")
ray_ctx.init()
# Out:
# Current pyspark location is : /Users/liuruolan/spark-2.4.3-bin-hadoop2.7/python/lib/pyspark.zip/pyspark/__init__.py
# Start to getOrCreate SparkContext
# 2020-06-10 19:12:47,903	INFO resource_spec.py:212 -- Starting Ray with 2.98 GiB memory available for workers and up to 0.93 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# Successfully got a SparkContext
# 2020-06-10 19:12:48,346	INFO services.py:1148 -- View the Ray dashboard at localhost:8265
# {'node_ip_address': '192.168.101.6',
#  'redis_address': '192.168.101.6:36621',
#  'object_store_address': '/tmp/ray/session_2020-06-10_19-12-47_889742_11007/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-06-10_19-12-47_889742_11007/sockets/raylet',
#  'webui_url': 'localhost:8265',
#  'session_dir': '/tmp/ray/session_2020-06-10_19-12-47_889742_11007'}

# %%
# %%time
# fit train_df and validate with val_df, return the best trial as pipeline.
# the default recipe is SmokeRecipe,which runs one epoch and one iteration with only 1 random sample.
# you can change recipe by define `recipe` in `fit`. The recipes you can choose are SmokeRecipe, RandomRecipe, GridRandomRecipe and BayesRecipe.
pipeline = tsp.fit(train_df,
                   validation_df=val_df,
                   metric="mse",
                   recipe=LSTMGridRandomRecipe(
                              num_rand_samples=1,
                              epochs=2,
                              look_back=5, 
                              batch_size=[64]))
print("Training completed.")
# Out:
# == Status ==<br>Memory usage on this node: 5.2/8.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/4 CPUs, 0/0 GPUs, 0.0/2.98 GiB heap, 0.0/0.63 GiB objects<br>Result logdir: /Users/liuruolan/ray_results/automl<br>Number of trials: 3 (3 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name      </th><th>status    </th><th>loc  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout_2</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_1_units</th><th style="text-align: right;">  lstm_2_units</th><th>selected_features                                                                                                 </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.313123</td><td style="text-align: right;">0.00843594</td><td style="text-align: right;">           128</td><td style="text-align: right;">            16</td><td>[&quot;MONTH(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;HOUR(timestamp)&quot;, &quot;IS_AWAKE(timestamp)&quot;]                        </td><td style="text-align: right;">    10</td><td style="text-align: right;">         53.2266</td></tr>
# <tr><td>train_func_00001</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.308769</td><td style="text-align: right;">0.00181324</td><td style="text-align: right;">            32</td><td style="text-align: right;">            32</td><td>[&quot;DAY(timestamp)&quot;, &quot;IS_AWAKE(timestamp)&quot;, &quot;WEEKDAY(timestamp)&quot;, &quot;MONTH(timestamp)&quot;, &quot;HOUR(timestamp)&quot;]            </td><td style="text-align: right;">    10</td><td style="text-align: right;">         43.2366</td></tr>
# <tr><td>train_func_00002</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.285449</td><td style="text-align: right;">0.00127159</td><td style="text-align: right;">            64</td><td style="text-align: right;">            64</td><td>[&quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;WEEKDAY(timestamp)&quot;, &quot;HOUR(timestamp)&quot;, &quot;MONTH(timestamp)&quot;, &quot;IS_WEEKEND(timestamp)&quot;]</td><td style="text-align: right;">    10</td><td style="text-align: right;">         33.8559</td></tr>
# </tbody>
# </table><br><br>
# best log dir is  /Users/liuruolan/ray_results/automl/train_func_2_batch_size=64,dropout_2=0.28545,lr=0.0012716,lstm_1_units=64,lstm_2_units=64,selected_features=["IS_BUSY_HOURS(timest_2020-06-10_19-22-14z8ktz1aa
# The best configurations are:
# selected_features : ["IS_BUSY_HOURS(timestamp)", "WEEKDAY(timestamp)", "HOUR(timestamp)", "MONTH(timestamp)", "IS_WEEKEND(timestamp)"]
# model : LSTM
# lstm_1_units : 64
# dropout_1 : 0.2
# lstm_2_units : 64
# dropout_2 : 0.2854494723588456
# lr : 0.0012715913374798517
# batch_size : 64
# epochs : 2
# past_seq_len : 5
# Training completed.
# CPU times: user 5.99 s, sys: 1.52 s, total: 7.52 s
# Wall time: 1min 38s

# %% [markdown]
# ## 3. Test

# %%
# predict test_df with the best trial
pred_df = pipeline.predict(test_df)

# %%
pred_df.head(5)
# Out:
#             timestamp         value
# 0 2015-01-10 14:30:00  21700.798828
# 1 2015-01-10 15:00:00  22473.595703
# 2 2015-01-10 15:30:00  23185.164062
# 3 2015-01-10 16:00:00  23930.089844
# 4 2015-01-10 16:30:00  23180.808594

# %%
# prediction value start from 50
test_df[50:55]
# Out:
#              timestamp  value
# 50 2015-01-11 13:00:00  21296
# 51 2015-01-11 13:30:00  20381
# 52 2015-01-11 14:00:00  19508
# 53 2015-01-11 14:30:00  19210
# 54 2015-01-11 15:00:00  18255

# %%
# plot the predicted values and actual values
plot_result(test_df, pred_df)

# %%
# evaluate test_df
mse, smape = pipeline.evaluate(test_df, metrics=["mse", "smape"])
print("Evaluate: the mean square error is", mse)
print("Evaluate: the smape value is", smape)
# Out:
# Evaluate: the mean square error is 2084347.0317555715
# Evaluate: the smape value is 6.264603546081613

# %% [markdown]
# ## 4. save and restore

# %% [markdown]
# We provide save and restore interface to save the pipeline with the best trial for easily rebuilding.

# %%
# save the pipeline with best trial
pipeline.save("/tmp/saved_pipeline/my.ppl")
# Out:
# Pipeline is saved in /tmp/saved_pipeline/my.ppl
# '/tmp/saved_pipeline/my.ppl'

# %%
from zoo.automl.pipeline.time_sequence import load_ts_pipeline
new_pipeline = load_ts_pipeline("/tmp/saved_pipeline/my.ppl")
# Out:
# Restore pipeline from /tmp/saved_pipeline/my.ppl

# %%
# you can do predict and evaluate again
# we use test_df as input in order to compare results before and after restoration 
new_pred = new_pipeline.predict(test_df)

# %%
new_pred.head(5)
# Out:
#             timestamp         value
# 0 2015-01-10 14:30:00  21700.798828
# 1 2015-01-10 15:00:00  22473.595703
# 2 2015-01-10 15:30:00  23185.164062
# 3 2015-01-10 16:00:00  23930.089844
# 4 2015-01-10 16:30:00  23180.808594

# %%
# evaluate test_df
mse, smape = new_pipeline.evaluate(test_df, metrics=["mse", "smape"])
print("Evaluate: the mean square error is", mse)
print("Evaluate: the smape value is", smape)
# Out:
# Evaluate: the mean square error is 2084347.0317555715
# Evaluate: the smape value is 6.264603546081613

# %% [markdown]
# ## 5. continue training

# %% [markdown]
# We support continue training with incremental data using the best configuration searched and the trained model.

# %%
# review the initialization infomation if needed
new_pipeline.describe()
# Out:
# **** Initialization info ****
# future_seq_len: 1
# dt_col: timestamp
# target_col: value
# extra_features_col: None
# drop_missing: True

# %%
# Use val_df as incremental data
new_pipeline.fit(val_df,epoch_num=5)
# Out:
# Train on 1027 samples
# Epoch 1/5
# 1027/1027 [==============================] - 2s 2ms/sample - loss: 0.0369 - mean_squared_error: 0.0369
# Epoch 2/5
# 1027/1027 [==============================] - 0s 346us/sample - loss: 0.0315 - mean_squared_error: 0.0315
# Epoch 3/5
# 1027/1027 [==============================] - 0s 242us/sample - loss: 0.0315 - mean_squared_error: 0.0315
# Epoch 4/5
# 1027/1027 [==============================] - 0s 223us/sample - loss: 0.0314 - mean_squared_error: 0.0314
# Epoch 5/5
# 1027/1027 [==============================] - 0s 226us/sample - loss: 0.0300 - mean_squared_error: 0.0300
# Fit done!

# %%
# predict results of test_df
new_pred_df = new_pipeline.predict(test_df)
plot_result(test_df, new_pred_df)

# %%
# evaluate test_df
mse, smape = new_pipeline.evaluate(test_df, metrics=["mse", "smape"])
print("Evaluate: the mean square error is", mse)
print("Evaluate: the smape value is", smape)
# Out:
# Evaluate: the mean square error is 1152789.1570904497
# Evaluate: the smape value is 6.289218237282343

# %% [markdown]
# ## 6. multi step forecasting

# %% [markdown]
# You can do multi step forecasting by simply changing the `future_seq_len` option while creating a new `TimeSequencePredictor` object.

# %%
# build time sequence predictor
from zoo.automl.regression.time_sequence_predictor import *

# change future_seq_len into the step you want to forcast.
tsp = TimeSequencePredictor(future_seq_len=5,
                            dt_col="timestamp",
                            target_col="value",
                            extra_features_col=None)

# %%
# %%time
# you can specify the look back sequence length with a single number or a range of (min_len, max_len) in RandomRecipe.
pipeline = tsp.fit(train_df,
                   validation_df=val_df,
                   metric="mse",
                   recipe=LSTMGridRandomRecipe(
                              num_rand_samples=3,
                              epochs=2,
                              look_back=10,
                              training_iteration=10,
                              batch_size=[64]))
print("Training completed.")
# Out:
# == Status ==<br>Memory usage on this node: 5.2/8.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/4 CPUs, 0/0 GPUs, 0.0/2.98 GiB heap, 0.0/0.63 GiB objects<br>Result logdir: /Users/liuruolan/ray_results/automl<br>Number of trials: 9 (9 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name      </th><th>status    </th><th>loc  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout_2</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_1_units</th><th style="text-align: right;">  lstm_2_units</th><th>selected_features                                                                                                                       </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.389078</td><td style="text-align: right;">0.00884959</td><td style="text-align: right;">            64</td><td style="text-align: right;">            16</td><td>[&quot;IS_AWAKE(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;WEEKDAY(timestamp)&quot;, &quot;MONTH(timestamp)&quot;, &quot;HOUR(timestamp)&quot;]                        </td><td style="text-align: right;">    10</td><td style="text-align: right;">         80.2761</td></tr>
# <tr><td>train_func_00001</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.465498</td><td style="text-align: right;">0.0092753 </td><td style="text-align: right;">           128</td><td style="text-align: right;">            32</td><td>[&quot;HOUR(timestamp)&quot;, &quot;IS_WEEKEND(timestamp)&quot;, &quot;WEEKDAY(timestamp)&quot;, &quot;DAY(timestamp)&quot;]                                                    </td><td style="text-align: right;">    10</td><td style="text-align: right;">        101.352 </td></tr>
# <tr><td>train_func_00002</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.476273</td><td style="text-align: right;">0.00456712</td><td style="text-align: right;">           128</td><td style="text-align: right;">            64</td><td>[&quot;MONTH(timestamp)&quot;, &quot;HOUR(timestamp)&quot;, &quot;IS_AWAKE(timestamp)&quot;, &quot;IS_WEEKEND(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;]                     </td><td style="text-align: right;">    10</td><td style="text-align: right;">        101.774 </td></tr>
# <tr><td>train_func_00003</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.200662</td><td style="text-align: right;">0.00429588</td><td style="text-align: right;">            16</td><td style="text-align: right;">            16</td><td>[&quot;IS_WEEKEND(timestamp)&quot;, &quot;DAY(timestamp)&quot;, &quot;HOUR(timestamp)&quot;, &quot;WEEKDAY(timestamp)&quot;]                                                    </td><td style="text-align: right;">    10</td><td style="text-align: right;">         65.8277</td></tr>
# <tr><td>train_func_00004</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.292069</td><td style="text-align: right;">0.00973915</td><td style="text-align: right;">            64</td><td style="text-align: right;">            32</td><td>[&quot;DAY(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;IS_WEEKEND(timestamp)&quot;]                                                                 </td><td style="text-align: right;">    10</td><td style="text-align: right;">         75.67  </td></tr>
# <tr><td>train_func_00005</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.266685</td><td style="text-align: right;">0.00960102</td><td style="text-align: right;">           128</td><td style="text-align: right;">            64</td><td>[&quot;DAY(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;WEEKDAY(timestamp)&quot;, &quot;MONTH(timestamp)&quot;, &quot;IS_AWAKE(timestamp)&quot;]                         </td><td style="text-align: right;">    10</td><td style="text-align: right;">        111.733 </td></tr>
# <tr><td>train_func_00006</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.480067</td><td style="text-align: right;">0.00726   </td><td style="text-align: right;">            32</td><td style="text-align: right;">            16</td><td>[&quot;DAY(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;MONTH(timestamp)&quot;]                                                                      </td><td style="text-align: right;">    10</td><td style="text-align: right;">         71.0432</td></tr>
# <tr><td>train_func_00007</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.23937 </td><td style="text-align: right;">0.00716801</td><td style="text-align: right;">            32</td><td style="text-align: right;">            32</td><td>[&quot;DAY(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;MONTH(timestamp)&quot;, &quot;IS_WEEKEND(timestamp)&quot;, &quot;WEEKDAY(timestamp)&quot;, &quot;IS_AWAKE(timestamp)&quot;]</td><td style="text-align: right;">    10</td><td style="text-align: right;">         71.5565</td></tr>
# <tr><td>train_func_00008</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">          64</td><td style="text-align: right;">   0.299147</td><td style="text-align: right;">0.00360445</td><td style="text-align: right;">            64</td><td style="text-align: right;">            64</td><td>[&quot;IS_WEEKEND(timestamp)&quot;, &quot;IS_BUSY_HOURS(timestamp)&quot;, &quot;MONTH(timestamp)&quot;, &quot;IS_AWAKE(timestamp)&quot;, &quot;HOUR(timestamp)&quot;]                     </td><td style="text-align: right;">    10</td><td style="text-align: right;">         71.4657</td></tr>
# </tbody>
# </table><br><br>
# best log dir is  /Users/liuruolan/ray_results/automl/train_func_3_batch_size=64,dropout_2=0.20066,lr=0.0042959,lstm_1_units=16,lstm_2_units=16,selected_features=["IS_WEEKEND(timestamp_2020-06-10_19-30-27mshv49_b
# The best configurations are:
# selected_features : ["IS_WEEKEND(timestamp)", "DAY(timestamp)", "HOUR(timestamp)", "WEEKDAY(timestamp)"]
# model : LSTM
# lstm_1_units : 16
# dropout_1 : 0.2
# lstm_2_units : 16
# dropout_2 : 0.2006618704972502
# lr : 0.004295882243715079
# batch_size : 64
# epochs : 2
# past_seq_len : 10
# Training completed.
# CPU times: user 17.6 s, sys: 5.09 s, total: 22.7 s
# Wall time: 7min 22s

# %%
# test
# predict test_df with the best trial
pred_df = pipeline.predict(test_df)

# %%
pred_df.head(5)
# Out:
#             timestamp       value_0       value_1       value_2       value_3  \
# 0 2015-01-10 17:00:00  21393.033203  22883.492188  24506.210938  25773.054688
# 1 2015-01-10 17:30:00  23210.636719  24619.132812  25831.468750  26554.453125
# 2 2015-01-10 18:00:00  24702.031250  25740.035156  26387.738281  26523.074219
# 3 2015-01-10 18:30:00  25596.542969  26296.722656  26569.335938  26375.414062
# 4 2015-01-10 19:00:00  25930.916016  26381.808594  26452.949219  26124.605469
#
#         value_4
# 0  26350.150391
# 1  26671.152344
# 2  26204.542969
# 3  25840.994141
# 4  25533.148438

# %%
# plot multi step predicted values and actual values
# plot at most five step predict values for better view
plot_less_five_step_result(test_df, pred_df)

# %%
# plot only the first and the last step predict values and actual values
plot_first_last_step_result(test_df, pred_df)

# %%
# evaluate test_df
mse, smape = pipeline.evaluate(test_df, metrics=["mse", "smape"])
print("Evaluate: the mean square error is", mse)
print("Evaluate: the smape value is", smape)
# Out:
# Evaluate: the mean square error is [1936643.95895106 2645439.12328729 3501577.89607078 4035087.86776981
#  5185664.70039114]
# Evaluate: the smape value is [6.70797193 6.9852963  7.27435846 7.49838809 8.35769877]

# %%
ray_ctx.stop()
